% %% [markdown]
% ## Uppgift 1

% %%
A = [[11 -6];[12 -6]];
[S,D]=eig(A)
% Out:
% S =
%
%     0.6000    0.5547
%     0.8000    0.8321
%
%
% D =
%
%     3.0000         0
%          0    2.0000

% %% [markdown]
% ## Uppgift 2

% %%
A = rosser;
B = gallery(5);
%save('A.mat', 'A');
SB = eig(B)
format rat
SA = eig(A)
% Out:
% SB =
%
%   -0.0347 + 0.0258i
%   -0.0347 - 0.0258i
%    0.0138 + 0.0401i
%    0.0138 - 0.0401i
%    0.0419 + 0.0000i
%
%
% SA =
%
%   -20401/20
%        1/3165013166146
%      206/2101
%     1000
%     1000
%    52015/51
%     1020
%    20401/20

% %% [markdown]
% ## Uppgift 3

% %%
A = [-1i-6, 6; -12, -1i+11];
B = [3;4];
A*B
% Out:
% ans =
%
%        6        -    3i
%        8        -    4i

% %% [markdown]
% ## Uppgift 4

% %%
format rat
A = [0 2; 0.8 0.6];
[S,D] = eig(A);
A-eye(2)*(-2/5)
% Out:
% ans =
%
%        2/5            2
%        4/5            1

% %% [markdown]
% ## Uppgift 5

% %%
A = [[6 -4];[9 -6]];
A*A
% Out:
% ans =
%
%      0     0
%      0     0

% %% [markdown]
% ## Uppgift 6

% %%
A = [0 8*pi; -2*pi 0];
B = [0 2*pi; -8*pi 0];
A*B
B*A
% Out:
% ans =
%
%  -631.6547         0
%          0  -39.4784
%
%
% ans =
%
%   -39.4784         0
%          0 -631.6547

% %%
sub1 = subplot(2, 1, 1);
x = linspace(0, 100, 1000);
y = cos(x);
plot(sub1, x, y);
title('cos')
xlabel('x')
ylabel('y')

sub2 = subplot(2, 1, 2);
y = sin(x);
plot(sub2, x, y);
title('sin')
xlabel('x')
ylabel('y')
